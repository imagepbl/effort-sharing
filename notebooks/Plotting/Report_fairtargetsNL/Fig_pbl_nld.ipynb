# %% [markdown]
# ## Preambule

# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
# Out:
# C:\Users\dekkerm\AppData\Local\Temp\2\ipykernel_12400\3550119306.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ## Read data

# %%
xr_dataread = xr.open_dataset("K:/ECEMF/T5.2/PBL/xr_dataread.nc")
xr_nld_raw = xr.open_dataset("K:/ECEMF/T5.2/Allocations/PBL/xr_alloc_NLD.nc")
xr_eu_raw = xr.open_dataset("K:/ECEMF/T5.2/Allocations/PBL/xr_alloc_EU.nc")

# %%
rules = ["GF", "PCC", "PC", "AP", "ECPC", "GDR", "PCB", "PCB_lin"]
rulecolors = (
    np.array(
        [
            (90, 51, 36),
            (141, 145, 31),
            (0, 156, 223),
            (157, 0, 100),
            (230, 173, 31),
            (61, 29, 92),
            (255, 0, 0),
            (0, 100, 0),
        ]
    )
    / 256
)
rulenames = [
    r"Continuity ($\it{Grandfathering}$)",
    r"Continuity & Equality ($\it{Per}$ $\it{capita}$ $\it{convergence}$)",
    r"Equality ($\it{Immediate}$ $\it{per}$ $\it{capita}$)",
    r"Capability ($\it{Ability}$ $\it{to}$ $\it{pay}$)",
    r"Equality & Responsibility ($\it{Equal}$ $\it{cumulative}$ $\it{per}$ $\it{capita}$)",
    r"Capability & Responsibility ($\it{Greenhouse}$ $\it{Development}$ $\it{Rights}$)",
    r"Per capita budget",
    r"Per capita budget linear",
]

# %%
emis_1990 = xr_dataread.GHG_hist.sel(Region="NLD", Time=1990)
emis_1990_eu = xr_dataread.GHG_hist.sel(Region="EU", Time=1990)

# %% [markdown]
# ## Plot

# %%
dt = 0.5
xr_nld_post = xr_nld_raw.sel(Time=np.arange(2040, 2101))
xr_nld = xr_nld_raw.sel(Time=np.arange(2021, 2041))
xr_eu_post = xr_eu_raw.sel(Time=np.arange(2040, 2101))
xr_eu = xr_eu_raw.sel(Time=np.arange(2021, 2041))

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 12), facecolor="w", sharey=True)
for ax_i, ax in enumerate([ax1, ax2]):
    temp = [1.56, 2.00][ax_i]
    risk = [0.5, 0.33][ax_i]
    negemis = [0.3, 0.6][ax_i]
    basic_settings = {
        "Temperature": temp,
        "Risk": risk,
        "NegEmis": negemis,
        "NonCO2red": 0.5,
        "Scenario": "SSP2",
        "Convergence_year": 2050,
        "Discount_factor": 0,
        "Historical_startyear": 1990,
        "RCI_weight": "Half",
        "Capability_threshold": "Th",
    }
    ax.set_xlim([2015, 2053])
    ax.set_ylim([-400, 250])

    ax.plot(
        xr_dataread.Time,
        xr_dataread.GHG_hist.sel(Region="NLD"),
        lw=5,
        c="k",
        label="Historical emissions",
    )
    ax.plot(
        [1990, 1e5],
        [
            xr_dataread.GHG_hist.sel(Region="NLD", Time=1990),
            xr_dataread.GHG_hist.sel(Region="NLD", Time=1990),
        ],
        "--",
        c="silver",
        zorder=-1e9,
    )

    for rule_i, rule in enumerate(rules):
        dat = xr_nld.sel(**basic_settings, Timing="Immediate")[rule]
        ax.plot(xr_nld.Time, dat, lw=4, c=rulecolors[rule_i])
        ax.plot(
            xr_nld_post.Time,
            xr_nld_post.sel(**basic_settings, Timing="Immediate")[rule],
            lw=4,
            c=rulecolors[rule_i],
            alpha=0.15,
        )
        y1 = xr_nld.sel(
            {"Temperature": temp, "Risk": risk, "Convergence_year": 2050, "Timing": "Immediate"}
        ).max(
            dim=[
                "Scenario",
                "NonCO2red",
                "NegEmis",
                "Discount_factor",
                "Historical_startyear",
                "RCI_weight",
                "Capability_threshold",
            ],
            skipna=True,
        )[rule]
        y2 = xr_nld.sel(
            {"Temperature": temp, "Risk": risk, "Convergence_year": 2050, "Timing": "Immediate"}
        ).min(
            dim=[
                "Scenario",
                "NonCO2red",
                "NegEmis",
                "Discount_factor",
                "Historical_startyear",
                "RCI_weight",
                "Capability_threshold",
            ],
            skipna=True,
        )[rule]
        ax.fill_between(xr_nld.Time, y1, y2, where=y1 >= y2, color=rulecolors[rule_i], alpha=0.10)
        y1 = xr_nld_post.sel(
            {"Temperature": temp, "Risk": risk, "Convergence_year": 2050, "Timing": "Immediate"}
        ).max(
            dim=[
                "Scenario",
                "NonCO2red",
                "NegEmis",
                "Discount_factor",
                "Historical_startyear",
                "RCI_weight",
                "Capability_threshold",
            ],
            skipna=True,
        )[rule]
        y2 = xr_nld_post.sel(
            {"Temperature": temp, "Risk": risk, "Convergence_year": 2050, "Timing": "Immediate"}
        ).min(
            dim=[
                "Scenario",
                "NonCO2red",
                "NegEmis",
                "Discount_factor",
                "Historical_startyear",
                "RCI_weight",
                "Capability_threshold",
            ],
            skipna=True,
        )[rule]
        ax.fill_between(
            xr_nld_post.Time, y1, y2, where=y1 >= y2, color=rulecolors[rule_i], alpha=0.04
        )
        bbox = dict(boxstyle="round", fc="white", ec=rulecolors[rule_i])
        y1 = xr_nld.sel(
            {"Temperature": temp, "Risk": risk, "Convergence_year": 2050, "Timing": "Immediate"}
        ).max(
            dim=[
                "Scenario",
                "NonCO2red",
                "NegEmis",
                "Discount_factor",
                "Historical_startyear",
                "RCI_weight",
                "Capability_threshold",
            ],
            skipna=True,
        )[rule]
        y2 = xr_nld.sel(
            {"Temperature": temp, "Risk": risk, "Convergence_year": 2050, "Timing": "Immediate"}
        ).min(
            dim=[
                "Scenario",
                "NonCO2red",
                "NegEmis",
                "Discount_factor",
                "Historical_startyear",
                "RCI_weight",
                "Capability_threshold",
            ],
            skipna=True,
        )[rule]
        for year_i, year in enumerate([2030, 2040]):
            val = dat.sel(Time=year)
            valmn = y2.sel(Time=year)
            valmx = y1.sel(Time=year)
            if temp == 1.56:
                val_plot = val  # +[[18, 11, 9, -25, -5, 0, 0, 0][rule_i], [15, 5, -10, 5, -5, 0, 0, 0][rule_i]][year_i]
            if temp == 2.0:
                val_plot = val  # +[[5, 0, 0, 3, -15, 0, 0, 0][rule_i], [0, 5, 0, -3, -3, 0, 0, 0][rule_i]][year_i]
            if year == 2030:
                ax.plot(
                    [year, year],
                    [val, val],
                    "o",
                    lw=5,
                    ms=10,
                    label=rulenames[rule_i],
                    c=rulecolors[rule_i],
                )
            else:
                ax.plot([year, year], [val, val], "o", lw=5, ms=10, c=rulecolors[rule_i])
            ax.text(
                year + dt * 3,
                val_plot,
                str(np.round(-float((valmx - emis_1990) / emis_1990) * 100, 1))
                + " - "
                + str(np.round(-float((valmn - emis_1990) / emis_1990) * 100, 1))
                + "%",
                fontsize=10,
                va="center",
                ha="left",
            )
            ax.plot([year + dt * 3, year], [val_plot, val], lw=0.5, c=rulecolors[rule_i])

    # Policy stuff
    x = np.linspace(-1e3, 2040, 10)
    y1 = np.array([emis_1990 * (1 - 0.46)] * len(x))
    y2 = np.array([emis_1990 * (1 - 0.57)] * len(x))
    ax.fill_between(
        x,
        y1,
        y2,
        where=y1 >= y2,
        alpha=0.15,
        zorder=-1e9,
        color="none",
        hatch="xx",
        edgecolor="k",
        lw=0,
    )

    ax.plot([-1e3, 1e5], [0, 0], "k", zorder=-1e9)
    ax.plot([2030, 2030], [-1e3, 1e3], "--", c="silver", zorder=-1e9)
    ax.plot([2040, 2040], [-1e3, 1e3], "--", c="silver", zorder=-1e9)
    ax.plot(
        [-1e3, 1e5], [emis_1990 * (1 - 0.90), emis_1990 * (1 - 0.90)], "--", c="silver", zorder=-1e9
    )

    dt = 0.25
    ax.plot(
        [2030, 2030], [emis_1990 * (1 - 0.57), emis_1990 * (1 - 0.46)], "darkgrey", lw=2, zorder=-1
    )
    ax.plot(
        [2030 - dt, 2030 + dt],
        [emis_1990 * (1 - 0.46), emis_1990 * (1 - 0.46)],
        "darkgrey",
        lw=2,
        zorder=-1,
    )
    ax.plot(
        [2030 - dt, 2030 + dt],
        [emis_1990 * (1 - 0.57), emis_1990 * (1 - 0.57)],
        "darkgrey",
        lw=2,
        zorder=-1,
    )

    ax.text(
        2015.3, emis_1990, "Emissions in 1990", color="grey", va="bottom", ha="left", fontsize=13
    )
    ax.text(
        2015.3,
        emis_1990 * (1 - np.mean([0.46, 0.57])),
        "Current policy\nin 2030 (KEV)",
        color="grey",
        va="center",
        ha="left",
        fontsize=13,
    )
    ax.text(
        2015.3,
        emis_1990 * (1 - np.mean([0.90, 0.90])),
        "European target\nin 2040 (90%)",
        color="grey",
        va="center",
        ha="left",
        fontsize=13,
    )

    ax.xaxis.set_tick_params(labelsize=17)
    ax.yaxis.set_tick_params(labelsize=17)
    ax.set_title(["Within 1.5 degrees", "Well-below 2.0 degrees"][ax_i], fontsize=20)
ax2.legend(loc="lower left", fontsize=16)
ax1.set_ylabel("GHG emissions including LULUCF\nin the Netherlands [Mt CO$_2$e]", fontsize=20)
fig.tight_layout()
# plt.savefig("K:/Code/EffortSharing/Figures/PBL_report/Fig_NLD_new_nonumb.png", dpi=250)

# %%
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 12), facecolor='w', sharey=True)
# for ax_i, ax in enumerate([ax1, ax2]):
#     temp=[1.56, 2.00][ax_i]
#     risk=[0.5, 0.33][ax_i]
#     negemis = [0.3, 0.6][ax_i]
#     basic_settings = {'Temperature': temp, 'Risk': risk, 'NegEmis': negemis, 'NonCO2red': 0.5, 'Scenario':'SSP2', 'Convergence_year':2050, 'Discount_factor':0, 'Historical_startyear':1990, 'RCI_weight': 'Half', 'Capability_threshold': 'Th'}
#     ax.set_xlim([2015, 2053])
#     ax.set_ylim([-4000, 5000])

#     ax.plot(np.arange(1950, 2022), xr_dataread.GHG_hist.sel(Region='EU', Time=np.arange(1950, 2022)), lw=5, c='k', label='Historical emissions')
#     ax.plot([1990, 1e5], [xr_dataread.GHG_hist.sel(Region='EU', Time=1990), xr_dataread.GHG_hist.sel(Region='EU', Time=1990)], '--', c='silver', zorder=-1e9)

#     for rule_i, rule in enumerate(rules):
#         dat = xr_eu.sel(**basic_settings, Timing='Immediate')[rule]
#         ax.plot(xr_eu.Time, dat, lw=4, c=rulecolors[rule_i])
#         ax.plot(xr_eu_post.Time, xr_nld_post.sel(**basic_settings, Timing='Immediate')[rule], lw=4, c=rulecolors[rule_i], alpha=0.15)
#         y1 = xr_eu.sel({'Temperature': temp, 'Risk': risk, 'Convergence_year':2050, 'Timing': 'Immediate'}).max(dim=['Scenario', 'NonCO2red', 'NegEmis', 'Discount_factor', 'Historical_startyear', 'RCI_weight', 'Capability_threshold'], skipna=False)[rule]
#         y2 = xr_eu.sel({'Temperature': temp, 'Risk': risk, 'Convergence_year':2050, 'Timing': 'Immediate'}).min(dim=['Scenario', 'NonCO2red', 'NegEmis', 'Discount_factor', 'Historical_startyear', 'RCI_weight', 'Capability_threshold'], skipna=False)[rule]
#         ax.fill_between(xr_eu.Time, y1, y2, where=y1>=y2, color=rulecolors[rule_i], alpha=0.10)
#         y1 = xr_eu_post.sel({'Temperature': temp, 'Risk': risk, 'Convergence_year':2050, 'Timing': 'Immediate'}).max(dim=['Scenario', 'NonCO2red', 'NegEmis', 'Discount_factor', 'Historical_startyear', 'RCI_weight', 'Capability_threshold'], skipna=False)[rule]
#         y2 = xr_eu_post.sel({'Temperature': temp, 'Risk': risk, 'Convergence_year':2050, 'Timing': 'Immediate'}).min(dim=['Scenario', 'NonCO2red', 'NegEmis', 'Discount_factor', 'Historical_startyear', 'RCI_weight', 'Capability_threshold'], skipna=False)[rule]
#         ax.fill_between(xr_eu_post.Time, y1, y2, where=y1>=y2, color=rulecolors[rule_i], alpha=0.04)
#         bbox = dict(boxstyle="round", fc='white', ec=rulecolors[rule_i])
#         y1 = xr_eu.sel({'Temperature': temp, 'Risk': risk, 'Convergence_year':2050, 'Timing': 'Immediate'}).max(dim=['Scenario', 'NonCO2red', 'NegEmis', 'Discount_factor', 'Historical_startyear', 'RCI_weight', 'Capability_threshold'], skipna=False)[rule]
#         y2 = xr_eu.sel({'Temperature': temp, 'Risk': risk, 'Convergence_year':2050, 'Timing': 'Immediate'}).min(dim=['Scenario', 'NonCO2red', 'NegEmis', 'Discount_factor', 'Historical_startyear', 'RCI_weight', 'Capability_threshold'], skipna=False)[rule]
#         for year_i, year in enumerate([2030, 2040]):
#             val = dat.sel(Time=year)
#             valmn = y2.sel(Time=year)
#             valmx = y1.sel(Time=year)
#             if temp == 1.56: val_plot = val+[[80, 0, -50, -25, -5, 0][rule_i], [80, 0, -80, 80, -80, 0][rule_i]][year_i]
#             if temp == 2.0: val_plot = val+[[80, 0, 0, 80, -80, 0][rule_i], [50, 0, -80, 50, -50, 0][rule_i]][year_i]
#             if year == 2030: ax.plot([year, year], [val, val], 'o', lw=5, ms=10, label=rulenames[rule_i], c=rulecolors[rule_i])
#             else: ax.plot([year, year], [val, val], 'o', lw=5, ms=10, c=rulecolors[rule_i])
#             ax.text(year+dt*3, val_plot, str(np.round(-float((valmx-emis_1990_eu)/emis_1990_eu)*100,1))+' - '+str(np.round(-float((valmn-emis_1990_eu)/emis_1990_eu)*100,1))+'%', fontsize=16, va='center', ha='left')
#             ax.plot([year+dt*3, year], [val_plot, val], lw=0.5, c=rulecolors[rule_i])

#     # Policy stuff
#     ax.plot([-1e3, 1e5], [0, 0], 'k', zorder=-1e9)
#     ax.plot([2030, 2030], [-1e4, 1e4], '--', c='silver', zorder=-1e9)
#     ax.plot([2040, 2040], [-1e4, 1e4], '--', c='silver', zorder=-1e9)
#     ax.plot([-1e3, 1e5], [emis_1990_eu*(1-0.90), emis_1990_eu*(1-0.90)], '--', c='silver', zorder=-1e9)

#     ax.text(2015.3, emis_1990_eu, 'Emissions in 1990', color='grey', va='bottom', ha='left', fontsize=13)
#     ax.text(2015.3, emis_1990_eu*(1-np.mean([0.90, 0.90])), 'European target\nin 2040 (90%)', color='grey', va='center', ha='left', fontsize=13)

#     ax.xaxis.set_tick_params(labelsize=17)
#     ax.yaxis.set_tick_params(labelsize=17)
#     ax.set_title(['Within 1.5 degrees', 'Well-below 2.0 degrees'][ax_i], fontsize=20)
# ax2.legend(loc='lower left', fontsize=16)
# ax1.set_ylabel('GHG emissions including LULUCF\nin the EU [Mt CO$_2$e]', fontsize=20)
# fig.tight_layout()
# #plt.savefig("K:/Code/EffortSharing/Figures/PBL_report/Fig_EU_new.png", dpi=250)

# %%
# reg = 'NOR'
# xr_i_raw = xr.open_dataset("K:/ECEMF/T5.2/Allocations/xr_alloc_"+reg+"_pbl.nc")
# emis_1990_i = xr_dataread.GHG_hist.sel(Region=reg, Time=1990)
# xr_i_post = xr_i_raw.sel(Time=np.arange(2040, 2101))
# xr_i = xr_i_raw.sel(Time=np.arange(2021, 2041))

# %%
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 12), facecolor='w', sharey=True)
# for ax_i, ax in enumerate([ax1, ax2]):
#     temp=[1.56, 2.00][ax_i]
#     risk=[0.5, 0.33][ax_i]
#     negemis = [0.3, 0.6][ax_i]
#     basic_settings = {'Temperature': temp, 'Risk': risk, 'NegEmis': negemis, 'NonCO2red': 0.5, 'Scenario':'SSP2', 'Convergence_year':2050, 'Discount_factor':0, 'Historical_startyear':1990, 'RCI_weight': 'Half', 'Capability_threshold': 'Th'}
#     ax.set_xlim([2015, 2053])
#     ax.set_ylim([-1.1*np.max(xr_dataread.GHG_hist.sel(Region=reg, Time=np.arange(1950, 2022))), 1.1*np.max(xr_dataread.GHG_hist.sel(Region=reg, Time=np.arange(1950, 2022)))])

#     ax.plot(np.arange(1950, 2022), xr_dataread.GHG_hist.sel(Region=reg, Time=np.arange(1950, 2022)), lw=5, c='k', label='Historical emissions')
#     ax.plot([1990, 1e5], [xr_dataread.GHG_hist.sel(Region=reg, Time=1990), xr_dataread.GHG_hist.sel(Region='EU', Time=1990)], '--', c='silver', zorder=-1e9)

#     for rule_i, rule in enumerate(rules):
#         dat = xr_i.sel(**basic_settings, Timing='Immediate')[rule]
#         ax.plot(xr_i.Time, dat, lw=4, c=rulecolors[rule_i])
#         ax.plot(xr_i_post.Time, xr_i_post.sel(**basic_settings, Timing='Immediate')[rule], lw=4, c=rulecolors[rule_i], alpha=0.15)
#         y1 = xr_i.sel({'Temperature': temp, 'Risk': risk, 'Convergence_year':2050, 'Timing': 'Immediate'}).max(dim=['Scenario', 'NonCO2red', 'NegEmis', 'Discount_factor', 'Historical_startyear', 'RCI_weight', 'Capability_threshold'], skipna=True)[rule]
#         y2 = xr_i.sel({'Temperature': temp, 'Risk': risk, 'Convergence_year':2050, 'Timing': 'Immediate'}).min(dim=['Scenario', 'NonCO2red', 'NegEmis', 'Discount_factor', 'Historical_startyear', 'RCI_weight', 'Capability_threshold'], skipna=True)[rule]
#         ax.fill_between(xr_i.Time, y1, y2, where=y1>=y2, color=rulecolors[rule_i], alpha=0.10)
#         y1 = xr_i_post.sel({'Temperature': temp, 'Risk': risk, 'Convergence_year':2050, 'Timing': 'Immediate'}).max(dim=['Scenario', 'NonCO2red', 'NegEmis', 'Discount_factor', 'Historical_startyear', 'RCI_weight', 'Capability_threshold'], skipna=True)[rule]
#         y2 = xr_i_post.sel({'Temperature': temp, 'Risk': risk, 'Convergence_year':2050, 'Timing': 'Immediate'}).min(dim=['Scenario', 'NonCO2red', 'NegEmis', 'Discount_factor', 'Historical_startyear', 'RCI_weight', 'Capability_threshold'], skipna=True)[rule]
#         ax.fill_between(xr_i_post.Time, y1, y2, where=y1>=y2, color=rulecolors[rule_i], alpha=0.04)
#         bbox = dict(boxstyle="round", fc='white', ec=rulecolors[rule_i])
#         y1 = xr_i.sel({'Temperature': temp, 'Risk': risk, 'Convergence_year':2050, 'Timing': 'Immediate'}).max(dim=['Scenario', 'NonCO2red', 'NegEmis', 'Discount_factor', 'Historical_startyear', 'RCI_weight', 'Capability_threshold'], skipna=True)[rule]
#         y2 = xr_i.sel({'Temperature': temp, 'Risk': risk, 'Convergence_year':2050, 'Timing': 'Immediate'}).min(dim=['Scenario', 'NonCO2red', 'NegEmis', 'Discount_factor', 'Historical_startyear', 'RCI_weight', 'Capability_threshold'], skipna=True)[rule]
#         for year_i, year in enumerate([2030, 2040]):
#             val = dat.sel(Time=year)
#             valmn = y2.sel(Time=year)
#             valmx = y1.sel(Time=year)
#             if temp == 1.56: val_plot = val+[[80, 0, -50, -25, -5, 0][rule_i], [80, 0, -80, 80, -80, 0][rule_i]][year_i]
#             if temp == 2.0: val_plot = val+[[80, 0, 0, 80, -80, 0][rule_i], [50, 0, -80, 50, -50, 0][rule_i]][year_i]
#             if year == 2030: ax.plot([year, year], [val, val], 'o', lw=5, ms=10, label=rulenames[rule_i], c=rulecolors[rule_i])
#             # else: ax.plot([year, year], [val, val], 'o', lw=5, ms=10, c=rulecolors[rule_i])
#             # ax.text(year+dt*3, val_plot, str(np.round(-float((valmx-emis_1990_eu)/emis_1990_eu)*100,1))+' - '+str(np.round(-float((valmn-emis_1990_eu)/emis_1990_eu)*100,1))+'%', fontsize=16, va='center', ha='left')
#             # ax.plot([year+dt*3, year], [val_plot, val], lw=0.5, c=rulecolors[rule_i])

#     # Policy stuff
#     ax.plot([-1e3, 1e5], [0, 0], 'k', zorder=-1e9)
#     ax.plot([2030, 2030], [-1e4, 1e4], '--', c='silver', zorder=-1e9)
#     ax.plot([2040, 2040], [-1e4, 1e4], '--', c='silver', zorder=-1e9)
#     ax.plot([-1e3, 1e5], [emis_1990_i*(1-0.90), emis_1990_i*(1-0.90)], '--', c='silver', zorder=-1e9)

#     ax.text(2015.3, emis_1990_i, 'Emissions in 1990', color='grey', va='bottom', ha='left', fontsize=13)
#     ax.text(2015.3, emis_1990_i*(1-np.mean([0.90, 0.90])), 'European target\nin 2040 (90%)', color='grey', va='center', ha='left', fontsize=13)

#     ax.xaxis.set_tick_params(labelsize=17)
#     ax.yaxis.set_tick_params(labelsize=17)
#     ax.set_title(['Within 1.5 degrees', 'Well-below 2.0 degrees'][ax_i], fontsize=20)
# ax2.legend(loc='lower left', fontsize=16)
# ax1.set_ylabel('GHG emissions including LULUCF\nin '+reg+' [Mt CO$_2$e]', fontsize=20)
# fig.tight_layout()
# plt.savefig("K:/Code/EffortSharing/Figures/Fig_"+reg+".png", dpi=250)
